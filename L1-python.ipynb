# %% [markdown]
# ## Introduction
# Python is an interpreted language. It runs from the command line, or from its interpreted shell.
# Python language includes many ideas from structured, imperative, object-oriented and functional languages.
#
# It uses positional placement to structure statements and does not use semicolons or braces. Python programs get structured through indentation, i.e. code blocks are defined by their indentation.

# %% [markdown]
# ## Starting Jupyter
#
# Please install the Anaconda Distribution, it includes many libraries for Python. It is at: http://anaconda.org/
#
#
# After installing Anaconda, you can start the Anaconda Navigator and click on Jupyter Notebook. Or you can click the Jupyter Notebook at the Start menu.
#
# ![Anaconda Navigator](img/AnacondaNavigator.png)
#
# Jupyter will open a tab in the browser. Using the Jupyter menu File open your Jupyter notebook.
#
# ![Jupyter Home](img/JupyterHome.png)

# %% [markdown]
# ## Running code at Jupyter Notebook
#
# At the notebook cell, press the RUN key, or press CTRL-ENTER. If the code correct, the output will be displayed after the code cell.

# %% [markdown]
# ### For Info Only: Running at Command Line
#
#
# You can also edit any Python code in any editor. The IDLE editor is included in anaconda. You can also download the Thonny editor.
#
# To run, invoke the shell at command line by typing “python”. This will start the python interactive shell. You can type the python commands and it will run immediately. Hint: Ctrl-L to clear screen, Ctrl-Z to quit. However it is more convenient to use the IDLE editor (to run type: ‘idle’ on cmd shell)
#
# You can run the python script directly from the command line:
# >	python mycode.py
#
# To run a function directly:
# >	python –c ‘import.module; module.runthisfunction()’
#
# or create a statement like this in the file:
#
# 	if __name__ == ‘__main__’
# 		runthisfunction()

# %% [markdown]
# ### Simple Input/Output

# %%
print(1+1)

print ("Hello\nWorld")

# %%
input ("Enter a number:")

# %%
if 10>4:
 print("1")
else:
  print("2")
# Out:
# 1

# %%
#what is wrong with this code?

num=input("Enter a number")
if num==5:
  print("5")
elif num==11:
 print("11")
else:
  print("not 5 or 11")
# Out:
# Enter a number4
# not 5 or 11

# %% [markdown]
# ### Test Yourself
#
# You can create a new code cell to run code that you have created.
#
# Select menu: Insert | Insert Cell below to create a new cell [Or press 'B' when CellToobar is selected]. On the dropdown box at the tool bar select code (not markdown).

# %% [markdown]
# What is the result of the following code?
#
# ```python
# if 1+1 == 2:
#   if 2*2 == 8:
#     print("if")
#   else:
#     print("else")
# ```

# %% [markdown]
# What is the output of this code?
# ```python
# spam=7
# if spam<5:
#    print("five")
# if spam>8:
#    print("eight")
# ```
# A. nothing
# B. eight
# C. five
# D. 7

# %% [markdown]
# ### While/For Loops

# %%
i=1
while i<5:
   print(i)
   i=i+1
print("finish")

# %%
words=["hello","world","good"]
for word in words:
   print(word)

# %%
for ii in range(5):
   print(ii)

# %%
#The range function creates a sequential list of numbers
numbers=list(range(10))
print(numbers

# %%
#Range can be called with two arguments
numbers=list(range(3,8))
print(numbers)

# %%
#Range can be called with three arguments, the third argument determines the interval
numbers=list(range(3,8,2))
print(numbers)

# %% [markdown]
# ### Test Yourself
# What is the output of this code?
# ```python
# i=3
# while i>=0:
#   print(i)
#   i=i-1
# ```

# %% [markdown]
# ### Test Yourself
# Write code that prints even numbers less than 20 using the while loop.
#
# Note:
# To enter code you need to create a new code cell.
# Select menu: Insert | Insert Cell below to create a new cell. On the dropdown box at the tool bar select code (not markdown).

# %% [markdown]
# ### Data Structure: List

# %% [markdown]
# A list is created using square brackets with commas separating items
# [ item, item , item]

# %%
words=["Apple","Orange","Papaya"]
print(words[0])
print(words[1])

# %% [markdown]
# List may be nested [ item, [ item, item , item] item , item]

# %%
words=["Apple",["Eggs", "Scrambled"],"Papaya"]
print(words[1][0])

# %% [markdown]
# Strings can be indexed like a list

# %%
str="I am Good"
print(str[0])

# %%
#append
nums=[1,2,3]
nums.append(4)
print(nums)

# %%
#len
print(len(nums))

# %%
#insert
nums.insert(0,0)
print(nums)

# %%
#index
letters=['a','b','c']
print(letters.index('b'))

# %%
#Slices
sq=[0,1,4,9,16,25,36,49,64,81]
print(sq[2:6])
print(sq[0:1])
print(sq[:3])
print(sq[7:])
print(sq[::2]) #skip by 2
print(sq[2:8:3]) #skip by 3

# %%
#list comprenhension
cube=[i**3 for i in range(5)]
print(cube)

# %% [markdown]
# ### Test Yourself
# 1. Which line of code will cause an error?
# ```python
# num=[5,4,3,[2],1]
# print(num[0])
# print(num[3][0])
# print(num[5])
# ```
# 2. How many items are in the above num list?
# 3. What is the output of this code?
# ```python
# listA=[1,1,2,3,4,8,13]
# print(listA[listA[4]])
# ```
# 4. What is the output of this code?
# ```python
# sq=[0,1,4,9,16,25,36,49,64,81]
# print(sq[1::4])
# ```
# 5. Create a list of numbers multiplied by 10 in the range of 5 to 9 using List Comprehension.

# %% [markdown]
# ### Data Structures: Dictionaries
# Dictionaries are like Lists but with indexed by Keys instead of integers:
# { Key: item, Key: item, Key: item }
#
# Curly brackets are used to create Dictionaries. Square brackets are used (as in List) to retrieve items.

# %%
age={"David":34, "Lee": 24, "Ruby":32}
print(age["David"])

# %%
#Only immutable objects can be used as keys to dictionaries
bad = {  [1,2,3]: "one two three", }

# %%
#Keys can be assigned values
age["David"]=22
print(age["David"])

# %%
#To determine if a key is in the dictionary	
print ("David" in age)

# %%
#using get
pairs= {1: "apple", "orange": [2,3,4],True: False,None: "True",}
print(pairs.get("orange"))
print(pairs.get(7))

# %%
#check in or not in
nums={1:"one",2:"two",3:"three",}
print (1 in nums)
print(4 not in nums)

# %% [markdown]
# ### Test Yourself
# 1. Which of these values can’t be used as a dictionary key?
# A. “one two three”
# B. False
# C. {2:4,3:9,4:16}
# 2. What is the result of this code?
# ```python
# primes={1:2,2:3,4:7,7:17}
# print(primes[primes[4]])
# ```
# 3. Create a valid dictionary that stores the age of your friends.

# %% [markdown]
# ### Data Structures: Tuples
# Tuples are like Lists but they are immutable. Parentheses are used instead of square brackets for Lists.
#
# ( item, item , item )
#
# Tuples can also be created without parenthesis:
# ```python
# words="dog", "cat", "bird"
# ```

# %%
words=("dog", "cat", "bird")
print(words[0])
#tuple does not support item assignment
#words[0]="fish"

# %% [markdown]
# ### Test Yourself
# 1. What is the result of this code?
# ```python
# tuple=(1,(1,2,3))
# print(tuple[1])
# ```
# 1. What is the result of this code?
# ```python
# What is the result of this code?
# letters=("a","b","c","d","e")
# print(letters[:3])
# ```

# %% [markdown]
# ### Strings
# Strings are created using single or double quotation marks e.g. "item"
# ```python
# word1="hello world"
# word2='hello world'
# ```

# %%
#join: create a string from a list of strings

"--".join(["this","that"])

# %%
#replace
print("Hello cruel world".replace("cruel","beautiful"))

# %%
#startswith, endswith
print("this is a sentence".startswith("this"))
print("this is a sentence".endswith("sentence"))

# %%
#split
print("spam,eggs,ham".split(","))
print("spam,eggs,ham".split(";"))

# %% [markdown]
# ### Functions
# Functions are defined using the def keyword. Functions must be defined before it is called. The return statement is optional.
# ```python
# def my_function():
# print(“spam”)
#
# my_function()
# ```

# %%
#functions with argument
def do_twice(x,y):
   print(x+y)
   print(x+y)
do_twice(5,8)

# %%
#return statement
def max(x,y):
  if x>=y:
    return x
  else:
    return y

print(max(3,5))

# %% [markdown]
# #### Function as objects .
# Functions can be assigned and reassigned to variables

# %%
def mult(x,y):
   return x*y
a=4
b=7
operation=mult
print(operation(a,b))

# %% [markdown]
# #### Functions as arguments.

# %%
def add(x,y):
   return x+y
def do_twice(func,x,y):
   return func(func(x,y),func(x,y))
a=5
b=10
print(do_twice(add,a,b))

# %% [markdown]
# ### Test Yourself
#
# 1. Write a function "d-square that takes in the function "square" as an argument. The function "d-square" returns twice the value returned by the "square" function. The "square" function calculates the square of its argument.
#
#
# 2. What is the output of this code?
#
# ```python
# def test(func,arg):
#    return func(func(arg))
#
# def mult(x):
#   return x*x
#
# print test(mult,2))
# ```

# %% [markdown]
# ### Functional Programming
# Lambda
# Allows you to create anonymous functions (functions with no names) on the fly
#
# my_func(lambda x: 2*x,5)
#
# argument of the lambda: x
# actual argument of the lambda: 5
# body of the lambda function: 2*x

# %%
def my_func(f, arg):
    return f(arg)

my_func(lambda x: 2*x,5)

# %%
square=lambda x: x*x
print(square(2))

# %% [markdown]
# ### Test Yourself
#
# What is the result of this code?
# ```python
# triple=lambda x: x*3
# add = lambda x, y: x+y
# print(add(triple(3),4))
# ```

# %%
#map
def add_five(x):
  return x+5
nums=[11,22,33,44,55]
result=list(map(add_five,nums))
print(result)

# %%
#filter
nums=[11,22,33,44,55]
res=list(filter(lambda x: x%2==0, nums))
print(res)

# %% [markdown]
# ### Test Yourself
#
# 1. Fill in the blanks to multiply each item in the list by 2 using the lambda syntax
# ```
# nums=[1,2,3]
# a=list(map(___ x:___ ,____))
# ```
# 2. Fill in the blanks to remove items greater than 44 from the list
# ```
# nums=[11,22,33,44,55]
# res=list(___(lambda x: ____, nums))
# print(res)
# ```

# %% [markdown]
# ### Classes
# Defining a class.
# \__init\__ is the constructor for the class which will be called first each time an object of the class is created.
# All methods must have self as their first parameter, so that methods can refer to itself.
#
# Instance variables have self as prefix: self.color and self.legs are instance variables.
# ```python
# class Cat:
# def __init__(self, color, legs):
#     self.color=color
#     self.legs=legs
# def call(self):
#     print(“Meow!”)
# felix=Cat(“ginger”,4)
# ```
#
# Inheritance.
# An inherited class will override methods from the superclass.
# ```python
# class SiameseCat(Cat): #SiameseCat inherit Cat
#    def call(self):
#         print(“meow meow”)
# ```
#
# Class methods  are marked with a classmethod decorator which require the cls parameter to be passed in.
# ```python
# class Rectangle:
# def __init__(self, width, height):
#    self.width=width
#    self.height=height
# @classmethod
# def new_square(cls,side_length):
#   return cls(side_length,side_length)
# ```
# Static methods are similar to class methods except they don’t require the cls parameter. Static methods behave like plain functions except for the fact that you can call them from an instance of the class.
#
# ```python
# class SimpleMaths:
#    def __init__(self, value):
#       self.value=value
#    @staticmethod
#    def  getPI():
#        return 3.14
# ```
# To call its own method, self.method() is prefixed in front of the method()
#
# ```python
# class Cat:
# def __init__(self, color, legs):
#     self.color=color
#     self.legs=legs
# def call(self):
#     print(“Meow!”)
# def greet(self):
#     self.call()
#     self.call()
# ```

# %%
class Cat:
    def __init__(self, color, legs):
        self.color=color
        self.legs=legs
    def call(self): 
        print("Meow!")

class SiameseCat(Cat): #SiameseCat inherit Cat
   def call(self):
        print("meow meow")

kitty=SiameseCat("black",4)
kitty.call()

# %%
class SimpleMaths:
   def __init__(self, value):
      self.value=value
   @staticmethod
   def  getPI():
       return 3.14

print(SimpleMaths.getPI())

# %%
class Cat:
    def __init__(self, color, legs):
        self.color=color
        self.legs=legs
    def call(self):
        print("Meow!")
    def greet(self):
        self.call()
        self.call()
felix=Cat("ginger",4)
felix.greet()

# %% [markdown]
# ### Test Yourself
#
# 1. What is the result of this code?
# ```python
# class A:
#    def method(self):
#       print(1)
# class B:
#    def method(self):
#       print(2)
# ```
# 2. Which of these is most likely a static method
# ```
# A. def spam(self,x,y)
# B. def spam(cls,x,y)
# C. def spam(x,y)
# ```
# 3. Fill in the blanks (underlines) to make sayHI() a class method
# ```python
# class Person:
#     def __init__(self, name):
#         self.name=name
#     _______
#        ___ sayHI(cls):
#          print(“hi”)
# ```
# 4. Fill in the blanks (yellow) to make the sayIntroduction() method print “Hello I am a John”
# ```python
# class Person:
#     def __init__(name):
#         ___.name=name
#     def sayHello(___):
#         print (“Hello”, end=’  ‘)
#     def sayIntroduction(___):
#         ___.sayHello()
#        print(“I am “, ____)
# c=Person(____)
# c.sayIntroduction()
# ```

# %% [markdown]
# ### Exception Handling
#
# Exceptions occur when there is something wrong with the code, or input and output. An Exception will be raised and the code will stop running.
# ```python
# n1=8
# n2=0
# print(n1/n2)
# >>
# ZeroDivisionError: division by zero
# ```
#
# Various types of Exceptions include:
# - ImportError: an import fails
# - IndexError: a list is indexed with an out-of-range number
# - NameError: an unknown variable is used
# - SyntaxError: the code can’t be parsed properly
# - TypeError: a function is called on a value of an inappropriate type
# - ValueError: a function is called on a value fo the correct type but with an inappropriate value.
#
# An Exception can be managed using a try/except so that code can continue running. If an error occurs in the try  block, control will be transferred to the except code block where the error can be fixed or ignored, but the code will continue to run.
# ```python
#    n1=8
#    n2=0
#    print(n1/n2)
# except ZeroDivisionError:
#   print(“oh uh, error”)
# >> oh uh, error
# ```
# A try can have multiple except. A try without any specific Exception will catch all errors.
# ```python
# try:
#    va=10
#    print(va+”hello”)
#    print(va/2)
# except ZeroDivisionError:
#    print(“Zero Divide!”)
# except(ValueError,TypeError):
#    print(“Error”)
# >>Error
# ```
#
# To ensure some code runs no matter what errors occur, a finally  statement is used. Code within a finally statement always runs after execution of the code in the try and possibly in the except blocks.
#
# ```python
# try:
#    va=10
#    print(va)
#    print(va/0)
# except ZeroDivisionError:
#    print(“Zero Divide!”)
# finally:
#    print(“this statement always run no matter what”)
# >>10
# Zero Divide!
# this statement always run no matter what
# ```

# %%
try:
   va=10
   print(va+”hello”)
   print(va/2)
except ZeroDivisionError:
   print(“Zero Divide!”)
except(ValueError,TypeError):
   print(“Error”)

# %% [markdown]
# ### File Handlilng
# ```python
# #open and close a file
# myfile=open("file.txt")
# myfile=open("file.txt","w") #open for read
# myfile=open("file.txt","r")  #open for new write
# myfile=open("file.txt","a")  #open for append
# myfile=open("file.txt","wb") #open write, binary
# myfile.close()
#
# #alternate way of opening a file
# with open("file.txt") as f:
#    print(f.read())
#
# #read a file
# file=open("file.txt","r")
# data=file.read() # read all
# data_byte=file.read(1) #read first byte
# data_line=file.readlines() #return a list of lines
#
# #read in line by line
# for line in file:
#   print(line)
# file.close()
#
#
# ```
# Write: returns the number of bytes successfully written to a file
# ```python
# file=open("file.txt","w")
# amount_written_to_file=file.write("line 1")
# ```

# %% [markdown]
# ### Test Yourself
#
# Fill in the blanks to try to open and read from a file. Print an error message in case of an exception.
# ```python
# try:
#    ___ open(“test.txt”) as ___:
#        print(f.read())
# ______
#    print(“Error”)
# ```
#
# Which of these statements is true?
# A. file.write(msg)==True
# B. file.write(msg)==len(msg)
# C. file.write(msg)==msg
#
# Fill in the blanks to open a file, read its content and print its length
# ```python
# file=___(“file.txt”,”_”)
# str=file.___()
# print(len(str))
# file.close()
# ```

# %% [markdown]
# ### Test Yourself
#
# 1. Write code to read in a file and count the number of words in it.
# 2. Write code to read in a file as above and write out the file using a substition cipher, e.g. replace a->z, b->y, c->x, etc (for all alphabets)
